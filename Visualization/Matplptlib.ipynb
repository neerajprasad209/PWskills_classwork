# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is my xlabel")
plt.ylabel("This is my ylabel")
plt.title("This is my title")
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.83264234, 0.60990169, 0.23778112, 0.10322303, 0.09250629,
#        0.99771529, 0.47389679, 0.92504607, 0.82096305, 0.40054829,
#        0.85603361, 0.42545424, 0.95739304, 0.95368321, 0.97422058,
#        0.84436537, 0.59948318, 0.52253875, 0.90155693, 0.41013914,
#        0.70832697, 0.7815811 , 0.82067474, 0.03877207, 0.07139309,
#        0.80749829, 0.06744144, 0.63726762, 0.09874339, 0.55425841,
#        0.83034533, 0.63439861, 0.02055802, 0.16328296, 0.15224631,
#        0.87395385, 0.79169733, 0.88642371, 0.19135933, 0.37487861,
#        0.8195422 , 0.39977208, 0.80014155, 0.34316252, 0.20637405,
#        0.10646291, 0.70819571, 0.64017668, 0.92560573, 0.57230192])

# %%
y
# Out:
# array([0.77159914, 0.64103131, 0.78945253, 0.21914227, 0.09836246,
#        0.44595796, 0.78611246, 0.14435496, 0.35925625, 0.88971833,
#        0.75034566, 0.31521517, 0.03261848, 0.87798198, 0.81495801,
#        0.21377672, 0.58209379, 0.4129921 , 0.06261993, 0.46236983,
#        0.99000314, 0.62282264, 0.28094973, 0.71329764, 0.02624609,
#        0.04006253, 0.69829992, 0.77212564, 0.16816673, 0.50291079,
#        0.27232142, 0.1084547 , 0.96602147, 0.58079542, 0.48211627,
#        0.40139272, 0.29132569, 0.23163352, 0.92329726, 0.30368835,
#        0.28134561, 0.89985382, 0.88927694, 0.72918393, 0.17034542,
#        0.57262997, 0.7086955 , 0.89771813, 0.66927005, 0.69307556])

# %%
colours = np.random.rand(50)
size = 500*np.random.rand(50)
plt.scatter(x,y,c=colours,s=size,alpha=.5)

# %%
x = ['a','b','c','d','e']

# %%
y =np.random.rand(5)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
y
# Out:
# array([0.13620948, 0.23475267, 0.7448207 , 0.97576223, 0.02470745])

# %%
x = ['a','b','c','d','e']
y =np.random.rand(5)
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(x,y,'--b')
plt.xlabel("This is my xlabel")
plt.ylabel("This is my ylabel")
plt.title("This is my title")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(x,y,'--b')
plt.xlabel("This is my xlabel")
plt.ylabel("This is my ylabel")
plt.title("This is my title")
plt.grid(visible=True)
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)

# %%
colours = np.random.rand(50)
size = 500*np.random.rand(50)
plt.scatter(x,y,c=colours,s=size,alpha=.5,marker='v')
plt.xlabel("xaxis")
plt.ylabel("yaxis")
plt.title("randam data")
plt.show()

# %%
size
# Out:
# array([234.04367897,  32.80235261, 412.63546328, 224.60061976,
#         56.70560903, 293.51366739, 494.9674103 , 377.24796442,
#        272.88501738, 160.87265704,  40.96941485, 285.39487697,
#        115.67184827, 475.87795799, 391.08505723,  31.49246257,
#         67.43584491, 352.01467956, 240.76904762, 360.14299077,
#         86.31003964, 107.49621862, 445.52870651, 358.65978955,
#        305.62446931,  75.04015709, 360.54642783, 186.81736237,
#        353.48990039, 441.55535097,   4.81445691, 243.78133993,
#         17.28786429,  76.62703442, 417.7496274 ,  99.24433621,
#        414.43773269, 424.40670265, 144.16456656, 109.98753793,
#        100.24838416, 443.08903478, 279.50603837, 225.90681567,
#        391.88931274, 392.77009536, 174.72278668,  65.63868896,
#        292.50020136, 406.20878505])

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,40,46,60,20,70]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,40,46,60,20,70]
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,5,6,7,8,9,1,5,3,2,6,1,5,4]

# %%
plt.hist(data)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,40,46,60,20,70]
colour= ["#e60000","#1a1aff","#ff1aff","#00cc00","#00e6e6","#ffff00"]
plt.scatter(x,y,c=colour,s=54.81445691)
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()
