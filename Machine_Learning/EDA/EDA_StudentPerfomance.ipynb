# %% [markdown]
# # Student Perfomance Datset

# %% [markdown]
# ## EDA Student Performance Indicator
#
# ### 1) Problem statement
# - This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.
#
#
# ### 2) Data Collection
# - Dataset Source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
# - The data consists of 8 column and 1000 rows.
#
# ### 3) Dataset Information
# - gender : sex of students  -> (Male/female)
# - race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
# - parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# - lunch : having lunch before test (standard or free/reduced)
# - test preparation course : complete or not complete before test
# - math score
# - reading score
# - writing score

# %%
from warnings import filterwarnings 
filterwarnings('ignore')

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# Reading The Dataset
df = pd.read_csv('https://raw.githubusercontent.com/neerajprasad209/Dataset/main/exams.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                 high school  free/reduced
# 1  female        group D             master's degree      standard
# 2  female        group A          associate's degree      standard
# 3    male        group C            some high school      standard
# 4  female        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          71             83             84
# 1                    none          82             81             89
# 2                    none          71             80             86
# 3                    none          74             72             61
# 4                    none          87             87             86

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.390000      70.158000      69.028000
# std      15.209445      14.879531      15.610795
# min       7.000000      19.000000      14.000000
# 25%      58.000000      61.000000      59.000000
# 50%      68.000000      71.000000      70.000000
# 75%      78.000000      81.000000      80.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# ### 3. Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %%
## Checking the Missing Values 
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Checking the Percentaage Of Null values
df.isnull().mean() *100
# Out:
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %%
## Checking Data types
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
## Checking Duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
## Checking unique data Type
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     76
# reading score                  73
# writing score                  77
# dtype: int64

# %%
## Checking stats of data
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.390000      70.158000      69.028000
# std      15.209445      14.879531      15.610795
# min       7.000000      19.000000      14.000000
# 25%      58.000000      61.000000      59.000000
# 50%      68.000000      71.000000      70.000000
# 75%      78.000000      81.000000      80.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# ## Insights or Observation
# - From the above description of numerical data,all means are very close to each other- between 66 and 69
# - All the standard deviation are also close- between 14.6- 15.19
# - While there is a minimum of 0 for maths,other are having 17 and 10 value

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                 high school  free/reduced
# 1  female        group D             master's degree      standard
# 2  female        group A          associate's degree      standard
# 3    male        group C            some high school      standard
# 4  female        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          71             83             84
# 1                    none          82             81             89
# 2                    none          71             80             86
# 3                    none          74             72             61
# 4                    none          87             87             86

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995    male        group C                 high school  free/reduced
# 996  female        group B           bachelor's degree      standard
# 997    male        group D                some college  free/reduced
# 998  female        group C            some high school      standard
# 999    male        group B                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 995                    none          59             62             60
# 996                    none          59             62             64
# 997               completed          61             56             60
# 998                    none          66             72             71
# 999               completed          71             70             74

# %%
[feature for feature in df.columns]
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
## Segrigate The Categorical and Numerical/continious feature
num = [feature for feature in df.columns if df[feature].dtype != 'object']
cat = [feature for feature in df.columns if df[feature].dtype == 'object']

# %%
num
# Out:
# ['math score', 'reading score', 'writing score']

# %%
cat
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df['gender'].value_counts()
# Out:
# male      504
# female    496
# Name: gender, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    247
# group B    212
# group E    141
# group A     81
# Name: race/ethnicity, dtype: int64

# %%
df['total_score'] = df['math score']+df['reading score']+df['writing score']
df['average'] = df['total_score']/3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                 high school  free/reduced
# 1  female        group D             master's degree      standard
# 2  female        group A          associate's degree      standard
# 3    male        group C            some high school      standard
# 4  female        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          71             83             84
# 1                    none          82             81             89
# 2                    none          71             80             86
# 3                    none          74             72             61
# 4                    none          87             87             86
#
#    total_score    average
# 0          238  79.333333
# 1          252  84.000000
# 2          237  79.000000
# 3          207  69.000000
# 4          260  86.666667

# %%
## Plottiing the map

fig,axis = plt.subplots(1,2,figsize=(14,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='gender')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Insights
# - Female student tend to perform well than male students

# %%
fig,axis = plt.subplots(1,3,figsize=(25,8))
plt.subplot(131)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='lunch')
plt.subplot(132)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='lunch')
plt.subplot(133)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='lunch')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Insights
# - Standard Lunch help students perform well in exams
# - Standard lunch helps perform well in exams be it a male of female

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                 high school  free/reduced
# 1  female        group D             master's degree      standard
# 2  female        group A          associate's degree      standard
# 3    male        group C            some high school      standard
# 4  female        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          71             83             84
# 1                    none          82             81             89
# 2                    none          71             80             86
# 3                    none          74             72             61
# 4                    none          87             87             86
#
#    total_score    average
# 0          238  79.333333
# 1          252  84.000000
# 2          237  79.000000
# 3          207  69.000000
# 4          260  86.666667

# %%
fig,axis = plt.subplots(1,3,figsize=(25,8))
plt.subplot(131)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='parental level of education')
plt.subplot(132)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='parental level of education')
plt.subplot(133)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='parental level of education')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# #####  Insights
# - In general parent's education don't help student perform well in exam.
# - 3rd plot shows that parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# - 2nd plot we can see there is no effect of parent's education on female students.

# %%
fig,axis = plt.subplots(1,3,figsize=(25,8))
plt.subplot(131)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='race/ethnicity')
plt.subplot(132)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='race/ethnicity')
plt.subplot(133)
sns.histplot(data=df[df.gender == 'female'],x='average',bins=30,kde=True,hue='race/ethnicity')
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %% [markdown]
# #####  Insights
# - Students of group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                 high school  free/reduced
# 1  female        group D             master's degree      standard
# 2  female        group A          associate's degree      standard
# 3    male        group C            some high school      standard
# 4  female        group C          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          71             83             84
# 1                    none          82             81             89
# 2                    none          71             80             86
# 3                    none          74             72             61
# 4                    none          87             87             86
#
#    total_score    average
# 0          238  79.333333
# 1          252  84.000000
# 2          237  79.000000
# 3          207  69.000000
# 4          260  86.666667

# %%
df.corr()
# Out:
#                math score  reading score  writing score  total_score   average
# math score       1.000000       0.833974       0.813250     0.923781  0.923781
# reading score    0.833974       1.000000       0.956585     0.973799  0.973799
# writing score    0.813250       0.956585       1.000000     0.967304  0.967304
# total_score      0.923781       0.973799       0.967304     1.000000  1.000000
# average          0.923781       0.973799       0.967304     1.000000  1.000000

# %%
sns.heatmap(data=df.corr(numeric_only=True),annot=True)
# Out:
# <AxesSubplot: >
